# %%
# !pip install xlrd

# %%
import pandas as pd

# %%
df = pd.read_excel('C:/lily/PowerBI_실습1/PowerBI_실습1/실습1_Main_Table.xlsx')

# %%
df_2 = pd.read_excel('C:/lily/PowerBI_실습1/PowerBI_실습1/실습1_DATE_Table.xlsx')

# %%
df.drop_duplicates()
# Out:
#          IS_INSIDE_TRADE   PROD_DEPT_NM                        CUST_NM  \
# 0                      0       LO Group                   Orci Sem LLC
# 1                      0       LO Group                   Orci Sem LLC
# 2                      0       LO Group                   Orci Sem LLC
# 3                      0       LO Group                   Orci Sem LLC
# 4                      0       LO Group                   Orci Sem LLC
# ...                  ...            ...                            ...
# 1048570                0  AMONG Coating  Tellus Suspendisse Associates
# 1048571                0  AMONG Coating  Tellus Suspendisse Associates
# 1048572                0  AMONG Coating  Tellus Suspendisse Associates
# 1048573                0  AMONG Coating  Tellus Suspendisse Associates
# 1048574                0  AMONG Coating  Tellus Suspendisse Associates
#
#                                CUSTLINE_NM      MATERIAL_NM CS_AREA_NM  \
# ...

# %%
print(df['PROD_DEPT_NM'].unique())
print(df['CUST_NM'].unique())
print(df['CUSTLINE_NM'].unique())
print(df['MATERIAL_NM'].unique())
print(df['CS_AREA_NM'].unique())
print(df['CS_PROC_NM'].unique())
print(df['CS_MAKER_NM'].unique())   # 4번 트리맵
print(df['CS_EQUIP_NM'].unique())
print(df['TECH_METHOD'].unique())
print(df['SERVICE'].unique())
print(df['CS_EQUIP_NM'].unique())
# Out:
# ['LO Group' '특수관리팀' 'FA Group' 'LEMON Group' 'ST Group' 'Col Group'
#  '표면기술팀' '기술개발팀' 'AMONG Coating' 'MONTRA Coating' 'BAM Coating']
# ['Orci Sem LLC' 'Magnis Limited' 'Orci Sem PC' 'Mus Proin Vel Ltd'
#  'Sodales LLP' 'Morbi Non Sapien Associates' 'Id PC' 'Diam Luctus PC'
#  'Elementum Dui Quis Company' 'Est Ac Facilisis Incorporated'
#  'Turpis In Company' 'Habitant Morbi Tristique Corporation' 'Nisi LLC'
#  'In Sodales Elit Corp.' 'Nisi Limited' 'Mattis Corp.'
#  'Ipsum Nunc Id Foundation' 'Sit PC' 'A Purus Ltd' 'Lectus Industries'
#  'Ultrices Iaculis Odio PC' 'Ultricies Adipiscing Enim Industries'
#  'Vestibulum Institute' 'Eget Foundation' 'Quis Corporation'
#  'Aliquet Proin Velit Inc.' 'Diam Lorem Auctor Industries'
#  'Ligula Tortor Dictum Inc.' 'Quam Dignissim LLC' 'Vulputate Velit Eu PC'
#  'Ut Nec Consulting' 'Tempor Corp.' 'At Associates' 'In Aliquet Ltd'
#  'Ultrices Iaculis Corp.' 'Metus In Lorem Company'
# ...

# %%
print(df['SERVICE'].unique())
# Out:
# ['Cleaning' 'Coating']

# %%
print(df['TECH_METHOD'].unique())
# Out:
# ['Cleaning' 'Super Coating' 'AMO Coating' 'Montra' 'BAM Coating']

# %%
print(df['PROD_DEPT_NM'].unique())
# Out:
# ['LO Group' '특수관리팀' 'FA Group' 'LEMON Group' 'ST Group' 'Col Group'
#  '표면기술팀' '기술개발팀' 'AMONG Coating' 'MONTRA Coating' 'BAM Coating']

# %%
df_2.head()
# Out:
#         Date  Year  Monthnumber  Daynumnber Month Day Quarter MonthCur  \
# 0 2017-07-01  2017            7           1    7월  1일      Q3       07
# 1 2017-07-02  2017            7           2    7월  2일      Q3       07
# 2 2017-07-03  2017            7           3    7월  3일      Q3       07
# 3 2017-07-04  2017            7           4    7월  4일      Q3       07
# 4 2017-07-05  2017            7           5    7월  5일      Q3       07
#
#    Monthchar
# 0          7
# 1          7
# 2          7
# 3          7
# 4          7
